# %%
import matplotlib.pyplot as matpy

# %%
f, (ax1, ax2) = matpy.subplots(1, 2, gridspec_kw = {'width_ratios':[1, 1]})

ax1.plot([1,2,3,4,5], [12,23,34,42,25], label="Train")
ax1.plot([12,23,34,42,25] ,[12,23,34,42,25],  label="Dev")
ax1.plot([42,74,32,65,61],[12,23,34,42,25], label="Test")
ax1.set_title("Plot 1")

ax2.plot([1,2,3,4,5], [12,23,34,42,25], label="Train")
ax2.plot([12,23,34,42,25] ,[12,23,34,42,25],  label="Dev")
ax2.plot([42,74,32,65,61],[12,23,34,42,25], label="Test")

ax2.set_title('Plot 2')

# %%
t = 2
axplot = matpy.subplot(t, t, 1)
axplot.plot(range(10), label="dsfsd")
axplot.set_ylabel("l1")
axplot.set_xlabel("l2")
axplot.set_title("l3")
axplot.legend()

# %%
f = matpy.figure(figsize=(10,3))

matpy.suptitle("Hi")
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)

ax.plot(range(10), label="dsfsd")
ax.set_ylabel("l1")
ax.set_xlabel("l2")
ax.set_title("l3")
ax.legend()

ax2.plot(range(10), label="dsfsd")
f.savefig("/tmp/sampele.png")
